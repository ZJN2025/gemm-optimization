# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# /workspace/ubuntu24.04/learn/gemm-optimization/.venv/bin/python
# 3.12.13 (main, Aug  7 2026, 02:25:39) [Clang 22.1.3 ]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(np.__version__)
print(pd.__version__)
# Out:
# 2.5.2
# 3.0.5
